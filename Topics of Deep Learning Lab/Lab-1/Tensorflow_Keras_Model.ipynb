# %% [markdown]
# Date - 02/02/2022
#
# # Tensorflow Basics 2 - Keras Model
#
# Name : Abhishek Aditya BS
#
# SRN : PES1UG19CS019
#
# Semester & Section : VI Semester & A Section

# %%
import numpy as np
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d54354b4-a7ee-4c08-bcf4-468548c88224" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d54354b4-a7ee-4c08-bcf4-468548c88224">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes.csv

# %%
data = np.loadtxt('diabetes.csv', delimiter=",", skiprows=1)
X = data[:,0:8]
y = data[:, 8]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,y)

# %%
model = Sequential()
model.add(Dense(12, activation="relu", input_dim=8))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %% [markdown]
# ### Loss - categorical_crossentropy
# ### Optimizer - Adagrad

# %%
model.compile(loss="categorical_crossentropy", optimizer="Adagrad", metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=250, batch_size=10)

# %%
_,accuracy = model.evaluate(x_test, y_test)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6823

# %%
print(accuracy * 100)
# Out:
# 68.22916865348816

# %% [markdown]
# # Screenshots of differnt losses and optimizers

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-27d93c38-ca78-46d1-bf90-035e0133484f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27d93c38-ca78-46d1-bf90-035e0133484f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screenshot 2022-02-02 at 12.01.50 PM.png to Screenshot 2022-02-02 at 12.01.50 PM.png
# Saving Screenshot 2022-02-02 at 12.03.41 PM.png to Screenshot 2022-02-02 at 12.03.41 PM.png
# Saving Screenshot 2022-02-02 at 12.06.11 PM.png to Screenshot 2022-02-02 at 12.06.11 PM.png
# Saving Screenshot 2022-02-02 at 12.08.06 PM.png to Screenshot 2022-02-02 at 12.08.06 PM.png
# Saving Screenshot 2022-02-02 at 12.11.25 PM.png to Screenshot 2022-02-02 at 12.11.25 PM.png
# ...

# %% [markdown]
# ![Screenshot 2022-02-02 at 12.20.04 PM.png](data:image/png;base64,...)![Screenshot 2022-02-02 at 12.16.27 PM.png](data:image/png;base64,...)![Screenshot 2022-02-02 at 12.12.51 PM.png](data:image/png;base64,...)![Screenshot 2022-02-02 at 12.11.25 PM.png](data:image/png;base64,...)![Screenshot 2022-02-02 at 12.08.06 PM.png](data:image/png;base64,...)![Screenshot 2022-02-02 at 12.06.11 PM.png](data:image/png;base64,...)![Screenshot 2022-02-02 at 12.03.41 PM.png](data:image/png;base64,...)![Screenshot 2022-02-02 at 12.01.50 PM.png](data:image/png;base64,...)
